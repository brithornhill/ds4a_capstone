# %%
from dash import Dash, dcc, html
import plotly.express as px
import pandas as pd
import plotly.io as pio
pio.renderers.default = 'plotly_mimetype+notebook'

# %%
# set color theme
colors = {
    'background': '#9BB6AA',
    'text': '#FFFFFF'
}

# load data
df = pd.read_csv("app_data.csv")

# %%
df.head()
# Out:
#    survey_year   age                                             race  gender  \
# 0         2014  37.0  Unavailable (Question Not Asked in Survey Year)  Female
# 1         2014  44.0  Unavailable (Question Not Asked in Survey Year)       M
# 2         2014  32.0  Unavailable (Question Not Asked in Survey Year)    Male
# 3         2014  31.0  Unavailable (Question Not Asked in Survey Year)    Male
# 4         2014  31.0  Unavailable (Question Not Asked in Survey Year)    Male
#
#           country us_state_or_territory self_employed tech_company  \
# 0   United States                    IL           NaN         True
# 1   United States                    IN           NaN        False
# 2          Canada                   NaN           NaN         True
# 3  United Kingdom                   NaN           NaN         True
# 4   United States                    TX           NaN         True
#
#      company_size family_history_of_mental_illness  ... mh_diagnosis  \
# 0            6-25                               No  ...          NaN
# 1  More than 1000                               No  ...          NaN
# 2            6-25                               No  ...          NaN
# 3          26-100                              Yes  ...          NaN
# 4         100-500                               No  ...          NaN
#
#   sought_treatment willing_to_discuss_mental_health_with_supervisors  \
# 0              Yes                                               Yes
# 1               No                                                No
# 2               No                                               Yes
# 3              Yes                                                No
# 4               No                                               Yes
#
#   employer_has_discussed_mental_health ease_of_taking_med_leave  \
# 0                                   No            Somewhat easy
# 1                           Don't know               Don't know
# 2                                   No       Somewhat difficult
# 3                                   No       Somewhat difficult
# 4                           Don't know               Don't know
#
#   willing_to_discuss_physical_health_in_an_interview  \
# 0                                              Maybe
# 1                                                 No
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   employer_provided_mental_health_benefits company_resources_to_learn_more  \
# 0                                      Yes                             NaN
# 1                               Don't know                             NaN
# 2                                       No                             NaN
# 3                                       No                             NaN
# 4                                      Yes                             NaN
#
#   anonymity_protected aware_of_employer_provided_mental_health_care_benefits
# 0                 Yes                                           Not sure
# 1          Don't know                                                 No
# 2          Don't know                                                 No
# 3                  No                                                Yes
# 4          Don't know                                                 No
#
# [5 rows x 25 columns]

# %%
fig = px.histogram(df, x="gender")
fig.show()
# Out:
# <div>                            <div id="07cbd084-5d00-4a88-bd94-497b051d38d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07cbd084-5d00-4a88-bd94-497b051d38d7")) {                    Plotly.newPlot(                        "07cbd084-5d00-4a88-bd94-497b051d38d7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["